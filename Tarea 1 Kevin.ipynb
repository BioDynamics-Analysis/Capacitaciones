# %%
import pandas as pd

# %%
pd.read_csv('C:/Users/user/Desktop/biodynamic/Capacitaciones/data/data1.csv')
# Out:
#      pool_id  cycle        date  surface(ha)  days      week  surviving  \
# 0          4   2020  2020-07-01         4.90     0  0.000000      1.000
# 1          4   2020  2020-07-02         4.90     1  0.142857      0.980
# 2          4   2020  2020-07-03         4.90     2  0.285714      0.970
# 3          4   2020  2020-07-04         4.90     3  0.428571      0.960
# 4          4   2020  2020-07-05         4.90     4  0.571429      0.950
# ..       ...    ...         ...          ...   ...       ...        ...
# 146        9   2020  2020-08-30         2.31    52  7.428571      0.794
# 147        9   2020  2020-08-31         2.31    53  7.571429      0.792
# 148        9   2020  2020-09-01         2.31    54  7.714286      0.790
# 149        9   2020  2020-09-02         2.31    55  7.857143      0.788
# 150        9   2020  2020-09-03         2.31    56  8.000000      0.786
#
#      density(shrimp)  density(shrimp/ha)  weight(g)  growth  biomass(kg)  \
# ...

# %%
#DataFrame
df = pd.read_csv('C:/Users/user/Desktop/biodynamic/Capacitaciones/data/data1.csv', index_col='date')
df.head()
# Out:
#             pool_id  cycle  surface(ha)  days      week  surviving  \
# date
# 2020-07-01        4   2020          4.9     0  0.000000       1.00
# 2020-07-02        4   2020          4.9     1  0.142857       0.98
# 2020-07-03        4   2020          4.9     2  0.285714       0.97
# 2020-07-04        4   2020          4.9     3  0.428571       0.96
# 2020-07-05        4   2020          4.9     4  0.571429       0.95
#
#             density(shrimp)  density(shrimp/ha)  weight(g)  growth  \
# date
# 2020-07-01         998000.0       203673.469388        NaN    0.00
# 2020-07-02         978040.0       199600.000000       0.15    0.00
# 2020-07-03         968060.0       197563.265306       0.18    0.03
# 2020-07-04         958080.0       195526.530612       0.24    0.06
# 2020-07-05         948100.0       193489.795918       0.30    0.06
#
#             biomass(kg)  biomass(kg/ha)  food(kg)         food(kg/ha)  \
# date
# ...

# %%
df.groupby('pool_id')['weight(g)']
df3 = df.groupby('pool_id')[['weight(g)']].agg(['min','mean','max'])

# %%
df['weektotal'] = df['days']//7
df2 = df.groupby(['pool_id','weektotal'])['weight(g)'].mean()

# %%
df[['weight(g)','pool_id']].groupby('pool_id').agg({
    'weight(g)':'mean',
    'weight(g)': 'min'
})
# Out:
#          weight(g)
# pool_id
# 4             0.15
# 9             0.30

# %%
#DataFrame promedio2
df.groupby('pool_id') ['weight(g)'].mean()
df.groupby('pool_id') ['weight(g)'].agg(['max','min','mean'])
# Out:
#            max   min      mean
# pool_id
# 4        22.00  0.15  9.579366
# 9        14.37  0.30  6.377544

# %%
#DataFrame promedio supervivencia 3
df.groupby('pool_id') ['surviving'].mean()
# Out:
# pool_id
# 4    0.812199
# 9    0.864860
# Name: surviving, dtype: float64

# %%
#Filtrado con apply survivin >promedio
df[ df['surviving'].apply(lambda x: x>0.86) ]
df[ df['surviving']>0.86 ]
# Out:
#             pool_id  cycle  surface(ha)  days      week  surviving  \
# date
# 2020-07-01        4   2020         4.90     0  0.000000     1.0000
# 2020-07-02        4   2020         4.90     1  0.142857     0.9800
# 2020-07-03        4   2020         4.90     2  0.285714     0.9700
# 2020-07-04        4   2020         4.90     3  0.428571     0.9600
# 2020-07-05        4   2020         4.90     4  0.571429     0.9500
# ...             ...    ...          ...   ...       ...        ...
# 2020-08-06        9   2020         2.31    28  4.000000     0.8685
# 2020-08-07        9   2020         2.31    29  4.142857     0.8670
# 2020-08-08        9   2020         2.31    30  4.285714     0.8655
# 2020-08-09        9   2020         2.31    31  4.428571     0.8635
# 2020-08-10        9   2020         2.31    32  4.571429     0.8615
#
#             density(shrimp)  density(shrimp/ha)  weight(g)  growth  \
# date
# 2020-07-01         998000.0       203673.469388        NaN    0.00
# ...

# %%
#DataFrame promedio crecimiemto 4 semanal
df.groupby('week') ['growth'].mean()
df.groupby('week') ['growth'].agg(['max','min'])
# Out:
#             max   min
# week
# 0.000000   0.00  0.00
# 0.142857   0.11  0.00
# 0.285714   0.12  0.03
# 0.428571   0.12  0.06
# 0.571429   0.12  0.06
# ...         ...   ...
# 12.571429  0.50  0.50
# 12.714286  0.50  0.50
# 12.857143  0.33  0.33
# 13.000000  0.33  0.33
# 13.142857  0.34  0.34
#
# [93 rows x 2 columns]

# %%
#DataFrame comida/biomasa 1
df['fo/bio'] = df['food(kg)']/df['biomass(kg)'] 
df.head()
# Out:
#             pool_id  cycle  surface(ha)  days      week  surviving  \
# date
# 2020-07-01        4   2020          4.9     0  0.000000       1.00
# 2020-07-02        4   2020          4.9     1  0.142857       0.98
# 2020-07-03        4   2020          4.9     2  0.285714       0.97
# 2020-07-04        4   2020          4.9     3  0.428571       0.96
# 2020-07-05        4   2020          4.9     4  0.571429       0.95
#
#             density(shrimp)  density(shrimp/ha)  weight(g)  growth  \
# date
# 2020-07-01         998000.0       203673.469388        NaN    0.00
# 2020-07-02         978040.0       199600.000000       0.15    0.00
# 2020-07-03         968060.0       197563.265306       0.18    0.03
# 2020-07-04         958080.0       195526.530612       0.24    0.06
# 2020-07-05         948100.0       193489.795918       0.30    0.06
#
#             biomass(kg)  biomass(kg/ha)  food(kg)         food(kg/ha)  \
# date
# ...
