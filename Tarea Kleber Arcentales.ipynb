# %%
import pandas as pd

# %%
df= pd.read_csv("data/data1.csv")

# %%
df.head(100)
# Out:
#     pool_id  cycle        date  surface(ha)  days      week  surviving  \
# 0         4   2020  2020-07-01         4.90     0  0.000000       1.00
# 1         4   2020  2020-07-02         4.90     1  0.142857       0.98
# 2         4   2020  2020-07-03         4.90     2  0.285714       0.97
# 3         4   2020  2020-07-04         4.90     3  0.428571       0.96
# 4         4   2020  2020-07-05         4.90     4  0.571429       0.95
# ..      ...    ...         ...          ...   ...       ...        ...
# 95        9   2020  2020-07-10         2.31     1  0.142857       0.98
# 96        9   2020  2020-07-11         2.31     2  0.285714       0.97
# 97        9   2020  2020-07-12         2.31     3  0.428571       0.96
# 98        9   2020  2020-07-13         2.31     4  0.571429       0.95
# 99        9   2020  2020-07-14         2.31     5  0.714286       0.94
#
#     density(shrimp)  density(shrimp/ha)  weight(g)  growth  biomass(kg)  \
# ...

# %%
#Ejercicio 1
df["alimentocamaron"]=df["Alimento acumulado [Kg]"]/df["biomass(kg/ha)"]
df["alimentocamaron"].head(100)
df
# Out:
#      pool_id  cycle        date  surface(ha)  days      week  surviving  \
# 0          4   2020  2020-07-01         4.90     0  0.000000      1.000
# 1          4   2020  2020-07-02         4.90     1  0.142857      0.980
# 2          4   2020  2020-07-03         4.90     2  0.285714      0.970
# 3          4   2020  2020-07-04         4.90     3  0.428571      0.960
# 4          4   2020  2020-07-05         4.90     4  0.571429      0.950
# ..       ...    ...         ...          ...   ...       ...        ...
# 146        9   2020  2020-08-30         2.31    52  7.428571      0.794
# 147        9   2020  2020-08-31         2.31    53  7.571429      0.792
# 148        9   2020  2020-09-01         2.31    54  7.714286      0.790
# 149        9   2020  2020-09-02         2.31    55  7.857143      0.788
# 150        9   2020  2020-09-03         2.31    56  8.000000      0.786
#
#      density(shrimp)  density(shrimp/ha)  weight(g)  ...  food(kg)  \
# ...

# %%
# Ejercicio 2
calculo=df.groupby(by="days")["weight(g)"].agg(["min","mean","max"])
df["calculo"]=
# Out:
#         min    mean    max
# days
# 0      0.30   0.300   0.30
# 1      0.15   0.280   0.41
# 2      0.18   0.355   0.53
# 3      0.24   0.445   0.65
# 4      0.30   0.535   0.77
# ...     ...     ...    ...
# 88    20.50  20.500  20.50
# 89    21.00  21.000  21.00
# 90    21.33  21.330  21.33
# 91    21.66  21.660  21.66
# 92    22.00  22.000  22.00
#
# [93 rows x 3 columns]

# %%
#Ejercicio 3
suv=df["surviving"].mean()
df[df["surviving"]>suv].head()
# Out:
#    pool_id  cycle        date  surface(ha)  days      week  surviving  \
# 0        4   2020  2020-07-01          4.9     0  0.000000       1.00
# 1        4   2020  2020-07-02          4.9     1  0.142857       0.98
# 2        4   2020  2020-07-03          4.9     2  0.285714       0.97
# 3        4   2020  2020-07-04          4.9     3  0.428571       0.96
# 4        4   2020  2020-07-05          4.9     4  0.571429       0.95
#
#    density(shrimp)  density(shrimp/ha)  weight(g)  ...  food(kg)  \
# 0         998000.0       203673.469388        NaN  ...       NaN
# 1         978040.0       199600.000000       0.15  ...      37.5
# 2         968060.0       197563.265306       0.18  ...      40.0
# 3         958080.0       195526.530612       0.24  ...      40.0
# 4         948100.0       193489.795918       0.30  ...      50.0
#
#           food(kg/ha)  type_feeding  Medicion Alimento acumulado [Kg]  \
# 0                 NaN           NaN       NaN                     0.0
# ...

# %%
df.columns
# Out:
# Index(['pool_id', 'cycle', 'date', 'surface(ha)', 'days', 'week', 'surviving',
#        'density(shrimp)', 'density(shrimp/ha)', 'weight(g)', 'growth',
#        'biomass(kg)', 'biomass(kg/ha)', 'food(kg)', 'food(kg/ha)',
#        'type_feeding', 'Medicion', 'Alimento acumulado [Kg]', 'FCA'],
#       dtype='object')

# %%
#Ejercicio 4
df["semanas"]=df["week"]//1
df.groupby(by="semanas")["growth"].agg(["min","max"])
# Out:
#            min     max
# semanas
# 0.0      0.000  0.1300
# 1.0      0.050  0.3600
# 2.0      0.140  0.4100
# 3.0      0.010  0.4000
# 4.0      0.200  0.3700
# 5.0      0.180  0.3800
# 6.0      0.170  0.3500
# 7.0      0.120  0.5425
# 8.0      0.130  0.3800
# 9.0      0.230  0.3000
# 10.0     0.300  0.3375
# 11.0    -0.510  0.6700
# 12.0     0.164  0.5000
# 13.0     0.330  0.3400

# %%
df.head(15)
# Out:
#     pool_id  cycle        date  surface(ha)  days      week  surviving  \
# 0         4   2020  2020-07-01          4.9     0  0.000000     1.0000
# 1         4   2020  2020-07-02          4.9     1  0.142857     0.9800
# 2         4   2020  2020-07-03          4.9     2  0.285714     0.9700
# 3         4   2020  2020-07-04          4.9     3  0.428571     0.9600
# 4         4   2020  2020-07-05          4.9     4  0.571429     0.9500
# 5         4   2020  2020-07-06          4.9     5  0.714286     0.9400
# 6         4   2020  2020-07-07          4.9     6  0.857143     0.9300
# 7         4   2020  2020-07-08          4.9     7  1.000000     0.9200
# 8         4   2020  2020-07-09          4.9     8  1.142857     0.9150
# 9         4   2020  2020-07-10          4.9     9  1.285714     0.9100
# 10        4   2020  2020-07-11          4.9    10  1.428571     0.9000
# 11        4   2020  2020-07-12          4.9    11  1.571429     0.8985
# ...
